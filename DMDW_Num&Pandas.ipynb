# %%
# !pip install --upgrade numpy pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 74.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 76.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.1 which is incompatible.
# ...

# %%
import math
x = 10
y = 3
result = math.fmod(x, y)
print(result)

n=10
math1 = math.factorial(n)
print(math1)

n2 = 4
math2 = math.pow(n2, 2)
print(math2)

n3 = 6
math3 = math.gcd(6)
print(math3)

n4 = 8
math4 = math.sqrt(n4)
print(math4)

x = 10
math5 = math.log(x)
print(math5)

x1 = 12
math6 = math.trunc(x1)
print(math6)

x2 = 14
math7 = math.floor(x2)
print(math7)

x3 = 30
math8 = math.sin(x3)
print(math8)

x4 = 30
math9 = math.radians(x4)
print(math9)

x5 = 30
math10 = math.degrees(x5)
print(math10)

x6 =24
math11 = math.lcm(24)
print(math11)
# Out:
# 1.0
# 3628800
# 16.0
# 6
# 2.8284271247461903
# 2.302585092994046
# 12
# 14
# -0.9880316240928618
# 0.5235987755982988
# 1718.8733853924696
# 24

# %%
# Experiment 2
# PROBLEM :- Given a list of numbers [2,4,6,8,10,12,14,16], perform the following tasks using Numpy functions;

# 1. Create a NumPy array from the given List.

import numpy as np
import pandas as pd

list1 =[2,4,6,8,10,12,14,16]

N_array = np.array(list1)
print("List in Pyhon:", list1)
print("Numpy Array in python:", N_array)

# 2. Calculate the Mean,median and standard deviation of the array.
# Out:
# List in Pyhon: [2, 4, 6, 8, 10, 12, 14, 16]
# Numpy Array in python: [ 2  4  6  8 10 12 14 16]
# 0    {10, 35, 20}
# dtype: object

# %%
import numpy as np
import pandas as pd

# Create a Series
ages = np.array([10, 20, 30])
series = pd.Series(ages)
series1 = pd.Series(ages, index=['Ram', 'Sita', 'Jain'])
print("Series:")
print(series)
print("\nSeries with index:")
print(series1)

# Create a DataFrame
data_frame = pd.DataFrame([
    ['Ram', 10, 'CSB'],
    ['Piyush', 20, 'ETB'],
    ['Sita', 30, 'MTB']
], columns=['Name', 'Age', 'Address'])

# Set 'Name' as the index
data_frame.set_index('Name', inplace=True)

print("\nData Frame with 'Name' as index:")
print(data_frame)
# Out:
# Series:
# 0    10
# 1    20
# 2    30
# dtype: int64
#
# Series with index:
# Ram     10
# Sita    20
# Jain    30
# dtype: int64
#
# Data Frame with 'Name' as index:
#         Age Address
# Name
# Ram      10     CSB
# Piyush   20     ETB
# Sita     30     MTB

# %%
import pandas as pd

data_frame = pd.DataFrame([
    ['Neeraj Chopra', 26, 183, 86, 'Javelin Throw', 'Haryana', 'Olympic Gold Medalist', 5, 12000000, 'Bachelor of Arts'],
    ['Mirabai Chanu', 29, 150, 49, 'Weightlifting', 'Manipur', 'Olympic Silver Medalist', 4, 9000000, 'Bachelor of Arts'],
    ['PV Sindhu', 28, 179, 65, 'Badminton', 'Telangana', 'Olympic Silver & Bronze Medalist', 7, 20000000, 'MBA'],
    ['Ravi Kumar Dahiya', 27, 170, 57, 'Wrestling', 'Haryana', 'Olympic Silver Medalist', 3, 8000000, 'B.P.Ed'],
    ['Lovlina Borgohain', 26, 178, 69, 'Boxing', 'Assam', 'Olympic Bronze Medalist', 2, 6000000, 'BA in Sociology'],
    ['Saina Nehwal', 34, 165, 60, 'Badminton', 'Haryana', 'Olympic Bronze Medalist', 6, 15000000, 'Graduate'],
    ['Bajrang Punia', 30, 165, 65, 'Wrestling', 'Haryana', 'World Championship Bronze', 5, 7000000, 'MA'],
    ['Hima Das', 25, 168, 58, 'Athletics (Sprinter)', 'Assam', 'Asian Games Gold Medalist', 4, 4000000, 'BA'],
    ['Dipa Karmakar', 30, 152, 46, 'Gymnastics', 'Tripura', 'Commonwealth Bronze Medalist', 3, 5000000, 'BSc'],
    ['Vinesh Phogat', 29, 159, 56, 'Wrestling', 'Haryana', 'Asian Games Gold Medalist', 6, 7500000, 'BA in Physical Education'],
    ['Manpreet Singh', 32, 179, 75, 'Hockey', 'Punjab', 'Olympic Bronze (Team)', 5, 5500000, 'BA'],
    ['Rani Rampal', 30, 158, 60, 'Hockey', 'Haryana', 'Asian Games Silver', 4, 4500000, 'BA'],
    ['PR Sreejesh', 35, 183, 83, 'Hockey (Goalkeeper)', 'Kerala', 'Olympic Bronze (Team)', 6, 6000000, 'B.Com'],
    ['Sunil Chhetri', 40, 171, 70, 'Football', 'Secunderabad', 'All-time top scorer', 7, 9000000, 'BA'],
    ['Anju Bobby George', 47, 180, 64, 'Long Jump', 'Kerala', 'World Championship Bronze', 3, 5000000, 'BA'],
    ['Sakshi Malik', 32, 162, 62, 'Wrestling', 'Haryana', 'Olympic Bronze Medalist', 4, 7000000, 'MA'],
    ['Mary Kom', 41, 158, 51, 'Boxing', 'Manipur', '6-time World Champion', 8, 10000000, 'BA'],
    ['Deepika Kumari', 30, 165, 56, 'Archery', 'Jharkhand', 'World No. 1 Archer', 5, 4000000, 'BA'],
    ['Srikanth Kidambi', 32, 177, 72, 'Badminton', 'Andhra Pradesh', 'Commonwealth Gold', 4, 5000000, 'Graduate'],
    ['Parupalli Kashyap', 38, 176, 70, 'Badminton', 'Hyderabad', 'Commonwealth Gold', 3, 4500000, 'B.Com'],
    ['Nehra Kumar', 28, 180, 70, 'Athletics (400m)', 'Uttar Pradesh', 'National Champion', 2, 2000000, 'BA'],
    ['Amit Panghal', 29, 160, 52, 'Boxing', 'Haryana', 'Asian Games Gold', 4, 3500000, 'BA'],
    ['Manu Bhaker', 24, 163, 54, 'Shooting', 'Haryana', 'Youth Olympic Gold', 5, 3000000, 'Pursuing B.A.'],
    ['Saurabh Chaudhary', 23, 173, 60, 'Shooting', 'Uttar Pradesh', 'Asian Games Gold', 4, 4000000, 'B.Sc'],
    ['Abhinav Bindra', 42, 173, 65, 'Shooting', 'Punjab', 'Olympic Gold Medalist', 6, 10000000, 'MBA'],
    ['Gagan Narang', 41, 170, 70, 'Shooting', 'Telangana', 'Olympic Bronze', 5, 7000000, 'MBA'],
    ['Yogeshwar Dutt', 41, 165, 66, 'Wrestling', 'Haryana', 'Olympic Bronze', 5, 6000000, 'MA'],
    ['Ravindra Jadeja', 36, 175, 70, 'Cricket', 'Gujarat', 'ICC Champions Trophy Winner', 4, 8000000, '10+2'],
    ['KL Rahul', 33, 180, 72, 'Cricket', 'Karnataka', 'India Opener', 3, 10000000, 'B.Com'],
    ['Shikhar Dhawan', 39, 183, 75, 'Cricket', 'Delhi', 'ICC Champions Trophy Winner', 6, 12000000, 'Graduate'],
    ['Smriti Mandhana', 29, 168, 58, 'Cricket', 'Maharashtra', 'ICC Women Cricketer of the Year', 5, 7000000, 'B.Com'],
    ['Harmanpreet Kaur', 34, 160, 60, 'Cricket', 'Punjab', 'Women’s T20 Captain', 6, 8000000, 'BA'],
    ['Rani Patel', 26, 155, 52, 'Wrestling', 'Gujarat', 'National Champion', 2, 2500000, 'BA'],
    ['Ajay Thakur', 38, 183, 75, 'Kabaddi', 'Himachal Pradesh', 'Asian Games Gold', 5, 6000000, 'Graduate'],
    ['Pardeep Narwal', 28, 178, 70, 'Kabaddi', 'Haryana', 'Pro Kabaddi MVP', 4, 5000000, 'Graduate'],
    ['Rahul Chaudhari', 32, 180, 72, 'Kabaddi', 'Uttar Pradesh', 'Pro Kabaddi Star', 4, 5500000, 'BA'],
    ['Nithya Ramesh', 25, 170, 60, 'Athletics (1500m)', 'Tamil Nadu', 'South Asian Games Silver', 2, 2200000, 'BSc'],
    ['Arun Muthukrishnan', 27, 175, 66, 'Cycling', 'Tamil Nadu', 'National Champion', 2, 2300000, 'Diploma in Sports'],
    ['Swapna Barman', 28, 162, 63, 'Heptathlon', 'West Bengal', 'Asian Games Gold', 3, 3000000, 'BA'],
    ['Kamalpreet Kaur', 28, 183, 80, 'Discus Throw', 'Punjab', 'Olympian', 2, 2500000, 'BA'],
    ['Bhavani Devi', 32, 168, 55, 'Fencing', 'Tamil Nadu', 'Olympian', 3, 2800000, 'BA'],
    ['Arpinder Singh', 35, 180, 75, 'Triple Jump', 'Punjab', 'Asian Games Gold', 2, 2200000, 'BA'],
    ['Tejaswin Shankar', 27, 186, 78, 'High Jump', 'Delhi', 'CWG Bronze', 2, 2400000, 'BBA'],
    ['Annu Rani', 31, 166, 63, 'Javelin Throw', 'Uttar Pradesh', 'Asian Games Medalist', 3, 3200000, 'BA'],
    ['Priya Mohan', 23, 172, 58, 'Athletics (400m)', 'Karnataka', 'National Record Holder', 2, 2000000, 'BA'],
    ['Shaili Singh', 21, 170, 58, 'Long Jump', 'Uttar Pradesh', 'U20 Silver Medalist', 1, 1800000, 'Pursuing BA'],
    ['Aishwarya Mishra', 24, 168, 56, 'Athletics (400m)', 'Maharashtra', 'Inter-State Champion', 2, 1900000, 'BA'],
    ['Meghna Kumari', 27, 165, 54, 'Shooting', 'Rajasthan', 'National Champion', 2, 2100000, 'BSc'],
    ['Rekha Singh', 30, 162, 58, 'Boxing', 'Uttar Pradesh', 'State Champion', 1, 1500000, 'BA'],
], columns=['Name', 'Age', 'Height', 'weight', 'Sports', 'State', 'Achievements', 'Medals Won', 'Salary', 'Education'])

display(data_frame)
# Out:
#                   Name  Age  Height  weight                Sports  \
# 0        Neeraj Chopra   26     183      86         Javelin Throw
# 1        Mirabai Chanu   29     150      49         Weightlifting
# 2            PV Sindhu   28     179      65             Badminton
# 3    Ravi Kumar Dahiya   27     170      57             Wrestling
# 4    Lovlina Borgohain   26     178      69                Boxing
# 5         Saina Nehwal   34     165      60             Badminton
# 6        Bajrang Punia   30     165      65             Wrestling
# 7             Hima Das   25     168      58  Athletics (Sprinter)
# 8        Dipa Karmakar   30     152      46            Gymnastics
# 9        Vinesh Phogat   29     159      56             Wrestling
# 10      Manpreet Singh   32     179      75                Hockey
# 11         Rani Rampal   30     158      60                Hockey
# 12         PR Sreejesh   35     183      83   Hockey (Goalkeeper)
# ...
